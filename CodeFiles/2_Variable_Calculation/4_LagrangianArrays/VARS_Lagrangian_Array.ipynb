# %%
####################################
#ENVIRONMENT SETUP

# %%
#Importing Libraries
import numpy as np
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors
import matplotlib.ticker as ticker
import matplotlib.cm as cm
from matplotlib.colors import Normalize
from matplotlib.ticker import MaxNLocator
from matplotlib.ticker import ScalarFormatter
import matplotlib.gridspec as gridspec
import xarray as xr

import sys; import os; import time; from datetime import timedelta
import pickle
import h5py

# %%
#MAIN DIRECTORIES
def GetDirectories():
    mainDirectory='/mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/'
    mainCodeDirectory=os.path.join(mainDirectory,"Code/CodeFiles/")
    scratchDirectory='/mnt/lustre/koa/scratch/air673/'
    codeDirectory=os.getcwd()
    return mainDirectory,mainCodeDirectory,scratchDirectory,codeDirectory

[mainDirectory,mainCodeDirectory,scratchDirectory,codeDirectory] = GetDirectories()

# %%
#IMPORT CLASSES
sys.path.append(os.path.join(mainCodeDirectory,"2_Variable_Calculation"))
from CLASSES_Variable_Calculation import ModelData_Class, SlurmJobArray_Class, DataManager_Class

# %%
#IMPORT FUNCTIONS
sys.path.append(os.path.join(mainCodeDirectory,"2_Variable_Calculation"))
import FUNCTIONS_Variable_Calculation
from FUNCTIONS_Variable_Calculation import * # import NumericalFunctions

# %%
####################################
#LOADING CLASSES

# %%
#data loading class
ModelData = ModelData_Class(mainDirectory, scratchDirectory, simulationNumber=1)
#data manager class
DataManager = DataManager_Class(mainDirectory, scratchDirectory, ModelData.res, ModelData.t_res, ModelData.Nz_str,
                                ModelData.Np_str, dataType="LagrangianArrays", dataName="VARS",
                                dtype='float32')
# Out:
# === CM1 Data Summary ===
#  Simulation #:   1
#  Resolution:     1km
#  Time step:      5min
#  Vertical levels:34
#  Parcels:        1e6
#  Data file:      /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Model/cm1r20.3/run/cm1out_1km_5min_34nz.nc
#  Parcel file:    /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Model/cm1r20.3/run/cm1out_pdata_1km_5min_1e6np.nc
#  Time steps:     133
# =========================
#
# === DataManager Summary ===
#  inputDirectory #:   /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/TimeSplitModelData
#  outputDirectory #:   /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays
#  inputDataDirectory #:   /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/TimeSplitModelData/1km_5min_34nz/ModelData
#  inputParcelDirectory #:   /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/TimeSplitModelData/1km_5min_34nz/ParcelData
#  outputDataDirectory #:   /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS
# =========================

# %%
#JOB ARRAY SETUP
UsingJobArray=True

def GetNumJobs(res):
    if res=='1km':
        num_jobs=30
    elif res=='250m': 
        num_jobs=100
    return num_jobs
num_jobs = GetNumJobs(ModelData.res)
SlurmJobArray = SlurmJobArray_Class(total_elements=ModelData.Ntime, num_jobs=num_jobs, UsingJobArray=UsingJobArray)
start_job = SlurmJobArray.start_job; end_job = SlurmJobArray.end_job

def GetNumElements():
    num_elements = np.arange(ModelData.Ntime)[start_job:end_job]
    return num_elements
num_elements = GetNumElements()
# Out:
# Running timesteps from 0:132

# %%
####################################
#FUNCTIONS

# %%
def GetZYX(inputParcelDirectory, timeString):
    #Lagrangian Position Arrays
    ##############
    def grid_location(z,y,x):
        zf=ModelData.zf*1000; which_zh=np.clip(np.searchsorted(zf,z)-1,0,None).astype(np.uint16)
        #which_zh=np.where(which_zh == -1, 0, which_zh) 
        
        yf=ModelData.yf*1000; which_yh=np.clip(np.searchsorted(yf,y)-1,0,None).astype(np.uint16) 
        #which_yh=np.where(which_yh == -1, 0, which_yh) 
        
        xf=ModelData.xf*1000; which_xh=np.clip(np.searchsorted(xf,x)-1,0,None).astype(np.uint16)
        #which_xh=np.where(which_xh == -1, 0, which_xh) 
        
        return which_zh,which_yh,which_xh
    
    # print('Creating Lagrangian X,Y,Z Binary Arrays')
    x = DataManager.GetTimestepParcel(DataManager.inputParcelDirectory, timeString, variableName="x")
    y = DataManager.GetTimestepParcel(DataManager.inputParcelDirectory, timeString, variableName="y")
    z = DataManager.GetTimestepParcel(DataManager.inputParcelDirectory, timeString, variableName="z")
    Z,Y,X=grid_location(z,y,x)
    return z,x,Z,Y,X

# %%
def MakeLagrangianArray(inputDataDirectory, timeString,varnames,Z,Y,X): #FAST ADVANCED INDEXING VERSION
    # print('Making Variables Lagrangian Array')
    # Initialize dictionaries
    var_data_dict = {varname: CallVariable(ModelData, DataManager, timeString, varname) for varname in varnames}
    VAR = {varname: np.zeros_like(Z, dtype='float32') for varname in varnames}

    # print('Running')
    # Nt = len(data['time'])
    # Get Indices
    z_idx = Z
    y_idx = Y
    x_idx = X
    # ts = np.arange(Nt)[:, None]
    # t_idx = np.broadcast_to(ts, Z.shape)

    for varname, var_data in var_data_dict.items():
        # VAR[varname] = var_data[t_idx, z_idx, y_idx, x_idx]
        VAR[varname] = var_data[z_idx, y_idx, x_idx]

    return [VAR[varname] for varname in varnames]
    # return VAR

# %%
def GetVariables(inputDataDirectory,timeString, Z,Y,X):
    # print('Making W and QCQI Lagrangian Array')
    varnames=['qv','qc','qi',
              'RH_vapor',
              'VMF_g','VMF_c',
              'HMC','convergence',
              'theta_v','theta_e',
              'MSE']
    [QV,QC,QI, 
     RH_vapor, 
     VMF_g,VMF_c, 
     HMC, CONVERGENCE,
     THETA_v,THETA_e,
     MSE] = MakeLagrangianArray(inputDataDirectory,timeString, varnames, Z,Y,X)
    QCQI = QC+QI
    
    outputDictionary = {"QV": QV, "QCQI": QCQI,
                        "RH_vapor": RH_vapor,
                        "VMF_g": VMF_g, "VMF_c": VMF_c,
                        "HMC": HMC, "CONVERGENCE": CONVERGENCE,
                        "THETA_v": THETA_v, "THETA_e": THETA_e,
                        "MSE": MSE,
                       }
    return outputDictionary

# %%
###############################################################
#RUNNING

# %%
#CALCULATING AND APPENDING TO DATA EACH TIMESTEP
for t in num_elements:
    if np.mod(t,1)==0: print(f'Current time {t}')

    #getting timestring for loading input data
    timeString = ModelData.timeStrings[t]

    #loading input variables
    z,x,Z,Y,X = GetZYX(DataManager.inputParcelDirectory, timeString)

    #calculating variables
    outputDictionary = GetVariables(DataManager,timeString, Z,Y,X)
    
    #outputting
    DataManager.SaveOutputTimestep(DataManager.outputDataDirectory, timeString, outputDictionary)
# Out:
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_5-35-00.h5
#
# Current time 68
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_5-40-00.h5
#
# Current time 69
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_5-45-00.h5
#
# Current time 70
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_5-50-00.h5
#
# Current time 71
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_5-55-00.h5
#
# Current time 72
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_6-00-00.h5
#
# Current time 73
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_6-05-00.h5
#
# Current time 74
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_6-10-00.h5
#
# Current time 75
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_6-15-00.h5
#
# Current time 76
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_6-20-00.h5
#
# Current time 77
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_6-25-00.h5
#
# Current time 78
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_6-30-00.h5
#
# Current time 79
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_6-35-00.h5
#
# Current time 80
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_6-40-00.h5
#
# Current time 81
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_6-45-00.h5
#
# Current time 82
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_6-50-00.h5
#
# Current time 83
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_6-55-00.h5
#
# Current time 84
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_7-00-00.h5
#
# Current time 85
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_7-05-00.h5
#
# Current time 86
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_7-10-00.h5
#
# Current time 87
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_7-15-00.h5
#
# Current time 88
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_7-20-00.h5
#
# Current time 89
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_7-25-00.h5
#
# Current time 90
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_7-30-00.h5
#
# Current time 91
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_7-35-00.h5
#
# Current time 92
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_7-40-00.h5
#
# Current time 93
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_7-45-00.h5
#
# Current time 94
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_7-50-00.h5
#
# Current time 95
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_7-55-00.h5
#
# Current time 96
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_8-00-00.h5
#
# Current time 97
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_8-05-00.h5
#
# Current time 98
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_8-10-00.h5
#
# Current time 99
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_8-15-00.h5
#
# Current time 100
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_8-20-00.h5
#
# Current time 101
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_8-25-00.h5
#
# Current time 102
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_8-30-00.h5
#
# Current time 103
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_8-35-00.h5
#
# Current time 104
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_8-40-00.h5
#
# Current time 105
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_8-45-00.h5
#
# Current time 106
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_8-50-00.h5
#
# Current time 107
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_8-55-00.h5
#
# Current time 108
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_9-00-00.h5
#
# Current time 109
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_9-05-00.h5
#
# Current time 110
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_9-10-00.h5
#
# Current time 111
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_9-15-00.h5
#
# Current time 112
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_9-20-00.h5
#
# Current time 113
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_9-25-00.h5
#
# Current time 114
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_9-30-00.h5
#
# Current time 115
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_9-35-00.h5
#
# Current time 116
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_9-40-00.h5
#
# Current time 117
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_9-45-00.h5
#
# Current time 118
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_9-50-00.h5
#
# Current time 119
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_9-55-00.h5
#
# Current time 120
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_10-00-00.h5
#
# Current time 121
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_10-05-00.h5
#
# Current time 122
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_10-10-00.h5
#
# Current time 123
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_10-15-00.h5
#
# Current time 124
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_10-20-00.h5
#
# Current time 125
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_10-25-00.h5
#
# Current time 126
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_10-30-00.h5
#
# Current time 127
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_10-35-00.h5
#
# Current time 128
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_10-40-00.h5
#
# Current time 129
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_10-45-00.h5
#
# Current time 130
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_10-50-00.h5
#
# Current time 131
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_10-55-00.h5
#
# Current time 132
# Saved timestep to output file: /mnt/lustre/koa/koastore/torri_group/air_directory/Projects/DCI-Project/Code/OUTPUT/Variable_Calculation/LagrangianArrays/1km_5min_34nz/VARS/VARS_1km_5min_34nz_11-00-00.h5
